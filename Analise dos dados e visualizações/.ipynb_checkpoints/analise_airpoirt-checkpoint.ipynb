# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../Dados/covid_airport.csv")
df.head()
# Out:
#    Unnamed: 0 AggregationMethod        Date  Version  \
# 0           0             Daily  2020-03-16      1.0
# 1           1             Daily  2020-03-16      1.0
# 2           2             Daily  2020-03-16      1.0
# 3           3             Daily  2020-03-16      1.0
# 4           4             Daily  2020-03-16      1.0
#
#                        AirportName  PercentOfBaseline  \
# 0       Boston Logan International                 97
# 1            Calgary International                100
# 2  Charlotte Douglas International                 91
# 3      Chicago OHare International                 94
# 4  Dallas/Fort Worth International                 82
#
#                                     Centroid       City           State  \
# 0  POINT(-71.0102909977065 42.3636330376787)     Boston   Massachusetts
# 1  POINT(-114.013122872131 51.1184753727795)    Calgary         Alberta
# 2  POINT(-80.9478114283204 35.2136892261228)  Charlotte  North Carolina
# ...

# %%
df["Version"].unique(), df["AggregationMethod"].unique() #colunas que não serão úteis
# Out:
# (array([1.]), array(['Daily'], dtype=object))

# %%
df["Unnamed: 0"].max(), df.shape # outra coluna que não será útil, acredito ser como uma id
# Out:
# (5935, (5936, 12))

# %%
df["Country"].unique()
# Out:
# array(['United States of America (the)', 'Canada', 'Australia', 'Chile'],
#       dtype=object)

# %%
df.groupby(["Date","City"]).mean()
# Out:
#                                 Unnamed: 0  Version  PercentOfBaseline
# Date       City
# 2020-03-16 Boston                      0.0      1.0               97.0
#            Calgary                     1.0      1.0              100.0
#            Charlotte                   2.0      1.0               91.0
#            Chicago                     3.0      1.0               94.0
#            College Park               11.0      1.0               92.0
# ...                                    ...      ...                ...
# 2020-10-16 SeaTac                   5931.0      1.0               72.0
#            South San Francisco      5929.0      1.0               51.0
#            Sydney                   5921.0      1.0               18.0
#            Urban Honolulu           5913.0      1.0               88.0
#            Winnipeg                 5935.0      1.0              100.0
#
# [5722 rows x 3 columns]

# %%
df.groupby(["State","Date"]).mean()
# Out:
#                        Unnamed: 0  Version  PercentOfBaseline
# State      Date
# Alberta    2020-03-16         4.5      1.0               81.5
#            2020-03-17        32.5      1.0               85.0
#            2020-03-18        60.5      1.0               84.5
#            2020-03-19        88.5      1.0               85.0
#            2020-03-20       116.5      1.0               91.0
# ...                           ...      ...                ...
# Washington 2020-10-12      5819.0      1.0               67.0
#            2020-10-13      5847.0      1.0               81.0
#            2020-10-14      5875.0      1.0               76.0
#            2020-10-15      5903.0      1.0               74.0
#            2020-10-16      5931.0      1.0               72.0
#
# [4896 rows x 3 columns]

# %%
df["Date"].unique() # seria interessante separar, também, por mês(?)
# Out:
# array(['2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19',
#        '2020-03-20', '2020-03-21', '2020-03-22', '2020-03-23',
#        '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27',
#        '2020-03-28', '2020-03-29', '2020-03-30', '2020-03-31',
#        '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04',
#        '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08',
#        '2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12',
#        '2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16',
#        '2020-04-17', '2020-04-18', '2020-04-19', '2020-04-20',
#        '2020-04-21', '2020-04-22', '2020-04-23', '2020-04-24',
#        '2020-04-25', '2020-04-26', '2020-04-27', '2020-04-28',
#        '2020-04-29', '2020-04-30', '2020-05-01', '2020-05-02',
#        '2020-05-03', '2020-05-04', '2020-05-05', '2020-05-06',
#        '2020-05-07', '2020-05-08', '2020-05-09', '2020-05-10',
#        '2020-05-11', '2020-05-12', '2020-05-13', '2020-05-14',
# ...

# %%
sns.scatterplot(data=df,x="Date",y="PercentOfBaseline") #tratar as datas
# Out:
# <AxesSubplot:xlabel='Date', ylabel='PercentOfBaseline'>

# %%
sns.scatterplot(data=df.sample(30),x="Date",y="PercentOfBaseline")
# Out:
# <AxesSubplot:xlabel='Date', ylabel='PercentOfBaseline'>

# %%
import matplotlib.pyplot as plt
import numpy as np


fig, ax = plt.subplots(figsize = (12,6))    
fig = sns.scatterplot(x = "Date", y = "PercentOfBaseline", data = df.sample(30), ax=ax)

x_dates = df['Date'].dt.strftime('%Y-%m-%d').sort_values().unique()
ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a389c6990824> in <module>
#       6 fig = sns.scatterplot(x = "Date", y = "PercentOfBaseline", data = df.sample(30), ax=ax)
#       7
# ----> 8 x_dates = df['Date'].dt.strftime('%Y-%m-%d').sort_values().unique()
#       9 ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...
