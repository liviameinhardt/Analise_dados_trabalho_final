# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../Dados/fifa_players.csv")
df
# Out:
#        Unnamed: 0  Counter      ID                Name  Age  \
# 0               0        0  158023            L. Messi   31
# 1               1        1   20801   Cristiano Ronaldo   33
# 2               2        2  190871           Neymar Jr   26
# 3               3        3  193080              De Gea   27
# 4               4        4  192985        K. De Bruyne   27
# ...           ...      ...     ...                 ...  ...
# 18202       18202    18202  238813        J. Lundstram   19
# 18203       18203    18203  243165  N. Christoffersson   19
# 18204       18204    18204  241638           B. Worman   16
# 18205       18205    18205  246268      D. Walker-Rice   17
# 18206       18206    18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# ...

# %%
df.info()
#df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 90 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   Counter                   18207 non-null  int64
#  2   ID                        18207 non-null  int64
#  3   Name                      18207 non-null  object
#  4   Age                       18207 non-null  int64
#  5   Photo                     18207 non-null  object
#  6   Nationality               18207 non-null  object
#  7   Flag                      18207 non-null  object
#  8   Overall                   18207 non-null  int64
#  9   Potential                 18207 non-null  int64
#  10  Club                      17966 non-null  object
#  11  Club_Logo                 18207 non-null  object
#  12  Value                     18207 non-null  object
# ...

# %%
df["Value"],df["Work_Rate"],df["Weight"] # converter para inteiro seria interessante (ver outras colunas)
# Out:
# (0        €110.5M
#  1           €77M
#  2        €118.5M
#  3           €72M
#  4          €102M
#            ...
#  18202       €60K
#  18203       €60K
#  18204       €60K
#  18205       €60K
#  18206       €60K
#  Name: Value, Length: 18207, dtype: object,
#  0        Medium/ Medium
#  1             High/ Low
#  2          High/ Medium
#  3        Medium/ Medium
#  4            High/ High
#                ...
#  18202    Medium/ Medium
#  18203    Medium/ Medium
#  18204    Medium/ Medium
#  18205    Medium/ Medium
#  18206    Medium/ Medium
#  Name: Work_Rate, Length: 18207, dtype: object,
#  0        159lbs
#  1        183lbs
#  2        150lbs
#  3        168lbs
#  4        154lbs
#            ...
#  18202    134lbs
#  18203    170lbs
#  18204    148lbs
#  18205    154lbs
#  18206    176lbs
#  Name: Weight, Length: 18207, dtype: object)

# %%
df["Skill_Moves"].unique() #será que tem a ver com o tipo de corpo
# Out:
# array([ 4.,  5.,  1.,  3.,  2., nan])

# %%
df.groupby("Body_Type")["Skill_Moves"].mean() #talvez
# Out:
# Body_Type
# Akinfenwa              2.000000
# C. Ronaldo             5.000000
# Courtois               1.000000
# Lean                   2.467820
# Messi                  4.000000
# Neymar                 5.000000
# Normal                 2.300047
# PLAYER_BODY_TYPE_25    4.000000
# Shaqiri                5.000000
# Stocky                 2.322807
# Name: Skill_Moves, dtype: float64

# %%
df.groupby("Preferred_Foot")["Skill_Moves"].mean() # realmente, parece que não tem relação
# Out:
# Preferred_Foot
# Left     2.511992
# Right    2.315816
# Name: Skill_Moves, dtype: float64

# %%
df.groupby("Body_Type").mean() #esse pode ser que de pra relacionar com muitos outros
# Out:
#                       Unnamed: 0      Counter             ID        Age  \
# Body_Type
# Akinfenwa            9501.000000  9501.000000  156321.000000  36.000000
# C. Ronaldo              1.000000     1.000000   20801.000000  33.000000
# Courtois               19.000000    19.000000  192119.000000  26.000000
# Lean                 9653.686146  9653.686146  219433.111111  23.864578
# Messi                   0.000000     0.000000  158023.000000  31.000000
# Neymar                  2.000000     2.000000  190871.000000  26.000000
# Normal               8881.343653  8881.343653  212097.239547  25.707409
# PLAYER_BODY_TYPE_25    26.000000    26.000000  209331.000000  26.000000
# Shaqiri               370.000000   370.000000  193348.000000  26.000000
# Stocky               7935.443860  7935.443860  205885.735965  26.742982
#
#                        Overall  Potential      Special  \
# Body_Type
# Akinfenwa            66.000000  66.000000  1586.000000
# ...

# %%
df2 = df[['Age','Potential','International_Reputation','Skill_Moves',"Acceleration"]].copy()

# %%
df2.groupby("Potential").mean() # esse tbm
# Out:
#                  Age  International_Reputation  Skill_Moves  Acceleration
# Potential
# 48         38.500000                  1.000000     1.500000     26.500000
# 50         29.000000                  1.000000     1.000000     26.000000
# 51         27.500000                  1.000000     1.500000     36.500000
# 52         30.200000                  1.000000     1.700000     49.400000
# 53         34.166667                  1.000000     1.666667     36.500000
# 54         31.000000                  1.142857     2.000000     52.428571
# 55         27.944444                  1.000000     1.888889     56.222222
# 56         28.083333                  1.000000     1.500000     45.791667
# 57         27.851064                  1.000000     1.765957     53.765957
# 58         26.425287                  1.000000     1.724138     53.701149
# 59         26.992000                  1.000000     1.888000     57.176000
# 60         26.606061                  1.006061     1.848485     56.163636
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Counter', 'ID', 'Name', 'Age', 'Photo', 'Nationality',
#        'Flag', 'Overall', 'Potential', 'Club', 'Club_Logo', 'Value', 'Wage',
#        'Special', 'Preferred_Foot', 'International_Reputation', 'Weak_Foot',
#        'Skill_Moves', 'Work_Rate', 'Body_Type', 'Real_Face', 'Position',
#        'Jersey_Number', 'Joined', 'Loaned_From', 'Contract_Valid_Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#sns.barplot(data=df,x="Value",y="BallControl") #tornar interiro para trabalhar com range
# Out:
# <AxesSubplot:xlabel='Value', ylabel='BallControl'>

# %%
sns.barplot(data=df,x="International_Reputation",y="BallControl")
# Out:
# <AxesSubplot:xlabel='International_Reputation', ylabel='BallControl'>

# %%
#sns.barplot(data=df,x="Preferred_Foot",y="Position")

# %%
sns.barplot(data=df,x="Skill_Moves",y="Body_Type")
# Out:
# <AxesSubplot:xlabel='Skill_Moves', ylabel='Body_Type'>
