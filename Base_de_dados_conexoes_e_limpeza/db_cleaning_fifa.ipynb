# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 150)

# %%
df = pd.read_csv('../Dados/fifa_players.csv')
#df.info()

# %%
df_cleaned = df.drop(columns={'Unnamed: 0', 'Counter', 'Photo', 'Flag', 'Club_Logo', 'Loaned_From', 'Real_Face', 'Work_Rate'})

non_na = df_cleaned.shape[1] - 27
df_cleaned.dropna(thresh=non_na, inplace=True) #Dropa jogadores com NA nas posições

flt = df_cleaned['Release_Clause'].notna()
df_cleaned = df_cleaned[flt]

df_cleaned.set_index('ID', inplace=True)

# %%
df_cleaned.head(5)
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# ID
# 158023           L. Messi   31   Argentina       94         94
# 20801   Cristiano Ronaldo   33    Portugal       94         94
# 190871          Neymar Jr   26      Brazil       92         93
# 193080             De Gea   27       Spain       91         93
# 192985       K. De Bruyne   27     Belgium       91         92
#
#                        Club    Value   Wage  Special Preferred_Foot  \
# ID
# 158023         FC Barcelona  €110.5M  €565K     2202           Left
# 20801              Juventus     €77M  €405K     2228          Right
# 190871  Paris Saint-Germain  €118.5M  €290K     2143          Right
# 193080    Manchester United     €72M  €260K     1471          Right
# 192985      Manchester City    €102M  €355K     2281          Right
#
#         International_Reputation  Weak_Foot  Skill_Moves   Body_Type Position  \
# ID
# 158023                       5.0        4.0          4.0       Messi       RF
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16643 entries, 158023 to 246269
# Data columns (total 81 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      16643 non-null  object
#  1   Age                       16643 non-null  int64
#  2   Nationality               16643 non-null  object
#  3   Overall                   16643 non-null  int64
#  4   Potential                 16643 non-null  int64
#  5   Club                      16643 non-null  object
#  6   Value                     16643 non-null  object
#  7   Wage                      16643 non-null  object
#  8   Special                   16643 non-null  int64
#  9   Preferred_Foot            16643 non-null  object
#  10  International_Reputation  16643 non-null  float64
#  11  Weak_Foot                 16643 non-null  float64
#  12  Skill_Moves               16643 non-null  float64
# ...

# %%
def remove_plus_sing(string):
    print(string)
    if string[-2] != '+':
        raise TypeError('Penúltimo dígito de {} não é um "+" - Ajustar função'.format(string))
    num = string[:-2]
    return int(num)

position_columns = df_cleaned.columns[20:46]

for column in position_columns:
    df_cleaned[column] = df_cleaned[column].apply(remove_plus_sing, convert_dtype=False)

# Desempenho extra, varia de acordo com o jogo (escalação, moral do time, etc).
# Valor padrão determinando pelo overall rating
# Out:
# 88+2
# 91+3
# 84+3
# nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5d9a6b9f9eae> in <module>
#       9
#      10 for column in position_columns:
# ---> 11     df_cleaned[column] = df_cleaned[column].apply(remove_plus_sing, convert_dtype=False)
#      12
#      13 # Desempenho extra, varia de acordo com o jogo (escalação, moral do time, etc).
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-33-5d9a6b9f9eae> in remove_plus_sing(string)
#       1 def remove_plus_sing(string):
# ...

# %%
df_cleaned.columns[20:46]
# Out:
# Index(['LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB'],
#       dtype='object')

# %%
df_cleaned.head(5)

# %%
def money_to_int(value):
    value = str(value)
    value = value[1:] # Remove €
    if value[-1] == '0': # There is a value of "€0"
        return float(0)
    money = float(value[:-1])
    multiplier = value[-1]
    if multiplier == 'K':
        return money * 1_000
    elif multiplier == 'M':
        return money * 1_000_000
    raise TypeError('Erro no multiplicador do valor {}'.format(value))

# %%
cols = ['Value', 'Wage', 'Release_Clause']

for col in cols:
    df_cleaned[col] = df_cleaned[col].apply(money_to_int)

# %%
df_cleaned['Joined'] = pd.to_datetime(df_cleaned['Joined'])
df_cleaned['Contract_Valid_Until'] = pd.to_numeric(df_cleaned['Contract_Valid_Until'])
df_cleaned.info()

# %%
df_cleaned.head(3)

# %%
def lbs_to_kg(value):
    if value[-3:] != 'lbs':
        raise TypeError('Erro de unidade: três úl timos dígitos de {} não são "lbs"'.format(value))
    value = float(value[:-3])
    return round(value * 0.4535923, 0)

# %%
df_cleaned['Weight'] = df_cleaned['Weight'].apply(lbs_to_kg)

# %%
df_cleaned.head(50)

# %%
def ft_to_meters(value):
    if value[1] != '\'':
        raise ValueError('Segundo dígito de {} precisa ser uma aspas simples'.format(value))
    inches = int(value[0]) * 12
    inches += int(value[2:])
    return round(float(inches * 0.0254), 2)

# %%
df_cleaned['Height'] = df_cleaned['Height'].apply(ft_to_meters)

# %%
df_cleaned.head(5)

# %%
df_cleaned.info()
